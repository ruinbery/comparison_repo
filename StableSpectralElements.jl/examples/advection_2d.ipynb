# %% [markdown]
# # `StableSpectralElements.jl` - 2D linear advection example
#
# First, let's load the packages used in this example.

# %%
import LinearAlgebra
using StableSpectralElements, OrdinaryDiffEq, .Threads
using Plots, Plots.PlotMeasures, TimerOutputs
using Profile, LinearAlgebra
using SparseArrays

# %% [markdown]
# We will solve the two-dimensional linear advection equation
# $$
# \partial_t U(\boldsymbol{x},t) + \nabla_{\boldsymbol{x}} \cdot (\boldsymbol{a} U(\boldsymbol{x},t)) = 0,  \quad \forall\, (\boldsymbol{x}, t) \in \Omega \times (0,T),
# $$
# with $a = [1,1]^{\mathrm{T}}$ and $\Omega = (0,L)^2$, where we take $L = 1$, and $T = 1$, and impose periodic boundary conditions as well as the initial condition
# $$
# U(\boldsymbol{x},0) = \sin(2\pi x_1 / L)\sin(2\pi x_2 / L), \quad \forall \, \boldsymbol{x} \in \Omega.
# $$

# %%
a = (5/4,sqrt(7)/4)  # advection velocity
#a = (1.0, 0.0)  # advection velocity
L = 1.0  # domain length
T = 1.0  # end time
conservation_law = LinearAdvectionEquation(a)
#initial_condition = DataSine(1.0, 8.0*π, a);
exact_solution= DataSine(1.0, 8.0*π, a);
#exact_solution = InitialDataSine(1.0, (2*π/L, 2*π/L));
# Out:
# DataSine{2}(1.0, 25.132741228718345, (1.25, 0.6614378277661477), 1)

# %% [markdown]
# Let's discretize the above problem using a `NodalMulti` discretization of degree $p = 4$, on an isoparametric (i.e. $p_{\mathrm{map}} = p$) curved triangular mesh with $M = 4$ edges in each direction. A skew-symmetric split form will be used to treat the curvilinear coordinate transformation in a provably stable manner. A central numerical flux is used to obtain an energy-conservative scheme.

# %%
M = 4
p = 4
h = 0.03
reference_approximation = ReferenceApproximation(
    ModalTensor(p), Tri(), mapping_degree=p)
#println(fieldnames(typeof(reference_approximation)))

form = StandardForm(mapping_form=SkewSymmetricMapping(), 
    inviscid_numerical_flux=LaxFriedrichsNumericalFlux(1.0))

mesh = unstructured_periodic_mesh(reference_approximation,
    (0.0,L), h)
#uniform_mesh = uniform_periodic_mesh(reference_approximation,
#    ((0.0,L),(0.0,L)), (M,M))

#mesh = warp_mesh(mesh, reference_approximation, 0.2, L)

spatial_discretization = SpatialDiscretization(mesh, 
    reference_approximation, project_jacobian=true)

#println(check_sbp_property(reference_approximation))
#println(check_sbp_property(spatial_discretization))
results_path = save_project(conservation_law,
     spatial_discretization, exact_solution, form, (0.0, T),
    "results/advection_2d_tensor/", overwrite=true, clear=true);

println(spatial_discretization.N_e)
# Out:
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] getindex(h::Dict{Int64, Set{Int64}}, key::Int64)
#
#     @ Base ./dict.jl:475
#
#   [2] get_neighbours
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/data_structures/triangulation/graph.jl:90 [inlined]
#
#   [3] get_neighbours
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/data_structures/triangulation/methods/graph.jl:36 [inlined]
#
#   [4] is_boundary_node(tri::DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Nothing}, Vector{Int64}, Set{Tuple{Int64, Int64}}, Vector{Int64}, Set{Tuple{Int64, Int64, Int64}}, NTuple{4, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, Tuple{SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, NTuple{27, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}}, Nothing}, i::Int64)
#
#     @ DelaunayTriangulation ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/predicates/boundaries_and_ghosts.jl:120
#
#   [5] _find_triangle(tri::DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Nothing}, Vector{Int64}, Set{Tuple{Int64, Int64}}, Vector{Int64}, Set{Tuple{Int64, Int64, Int64}}, NTuple{4, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, Tuple{SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, NTuple{27, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}}, Nothing}, q::Tuple{Float64, Float64}, k::Int64, store_history::Val{false}, history::Nothing, rng::Random.TaskLocalRNG, maxiters::Int64, cur_iter::Int64, concavity_protection::Bool, num_restarts::Int64, use_barriers::Val{false}, predicates::DelaunayTriangulation.AdaptiveKernel)
#
#     @ DelaunayTriangulation ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/point_location/jump_and_march.jl:1137
#
#   [6] #find_triangle#142
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/point_location/jump_and_march.jl:772 [inlined]
#
#   [7] add_point_bowyer_watson!(tri::DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Nothing}, Vector{Int64}, Set{Tuple{Int64, Int64}}, Vector{Int64}, Set{Tuple{Int64, Int64, Int64}}, NTuple{4, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, Tuple{SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, NTuple{27, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}}, Nothing}, new_point::Int64, initial_search_point::Int64, rng::Random.TaskLocalRNG, predicates::DelaunayTriangulation.AdaptiveKernel, update_representative_point::Bool, store_event_history::Val{false}, event_history::Nothing, peek::Val{false})
#
#     @ DelaunayTriangulation ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/unconstrained_triangulation.jl:154
#
#   [8] add_point_bowyer_watson!
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/unconstrained_triangulation.jl:152 [inlined]
#
#   [9] unconstrained_triangulation!(tri::DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{DelaunayTriangulation.Triangulation{Vector{Tuple{Float64, Float64}}, Set{Tuple{Int64, Int64, Int64}}, Vector{Int64}, DelaunayTriangulation.ZeroWeight{Float64}, Int64, Tuple{Int64, Int64}, Set{Tuple{Int64, Int64}}, Tuple{}, Dict{Tuple{Int64, Int64}, Tuple{Vector{Int64}, Int64}}, Dict{Int64, Vector{Int64}}, Dict{Int64, UnitRange{Int64}}, Dict{Int64, DelaunayTriangulation.RepresentativeCoordinates{Int64, Float64}}, DelaunayTriangulation.TriangulationCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Nothing}, Vector{Int64}, Set{Tuple{Int64, Int64}}, Vector{Int64}, Set{Tuple{Int64, Int64, Int64}}, NTuple{4, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, Tuple{SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}, NTuple{27, SubArray{Float64, 1, Memory{Float64}, Tuple{UnitRange{Int64}}, true}}}, Nothing}; predicates::DelaunayTriangulation.AdaptiveKernel, randomise::Bool, try_last_inserted_point::Bool, skip_points::Set{Int64}, num_sample_rule::typeof(DelaunayTriangulation.default_num_samples), rng::Random.TaskLocalRNG, insertion_order::Vector{Int64})
#
#     @ DelaunayTriangulation ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/unconstrained_triangulation.jl:462
#
#  [10] unconstrained_triangulation!
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/unconstrained_triangulation.jl:448 [inlined]
#
#  [11] _triangulate!
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/main.jl:179 [inlined]
#
#  [12] triangulate(points::Vector{Tuple{Float64, Float64}}; segments::Nothing, boundary_nodes::Nothing, predicates::DelaunayTriangulation.AdaptiveKernel, weights::DelaunayTriangulation.ZeroWeight{Float64}, IntegerType::Type{Int64}, EdgeType::Type{Tuple{Int64, Int64}}, TriangleType::Type{Tuple{Int64, Int64, Int64}}, EdgesType::Type{Set{Tuple{Int64, Int64}}}, TrianglesType::Type{Set{Tuple{Int64, Int64, Int64}}}, randomise::Bool, delete_ghosts::Bool, delete_empty_features::Bool, try_last_inserted_point::Bool, skip_points::Tuple{}, num_sample_rule::typeof(DelaunayTriangulation.default_num_samples), rng::Random.TaskLocalRNG, insertion_order::Vector{Int64}, recompute_representative_points::Bool, delete_holes::Bool, check_arguments::Bool, full_polygon_hierarchy::Nothing, boundary_enricher::Nothing, boundary_curves::Tuple{}, polygonise_n::Int64, coarse_n::Int64, enrich::Bool)
#
#     @ DelaunayTriangulation ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/main.jl:161
#
#  [13] triangulate
#
#     @ ~/.julia/packages/DelaunayTriangulation/z6I4Z/src/algorithms/triangulation/main.jl:118 [inlined]
#
#  [14] unstructured_periodic_mesh(reference_element::ReferenceApproximation{RefElemData{2, Tri, StartUpDG.Polynomial{StartUpDG.DefaultPolynomialType}, Int64, Tuple{Vector{Int64}, Vector{Int64}, Vector{Int64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Vector{Int64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Tuple{Matrix{Float64}, Matrix{Float64}}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Vector{Float64}, Vector{Float64}}, ModalTensor, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}}, WarpedTensorProductMap2D{SMatrix{5, 5, Float64, 25}, SArray{Tuple{5, 5, 5}, Float64, 3, 125}, SMatrix{5, 5, Int64, 25}, SMatrix{5, 5, Int64, 25}}, LinearMaps.CompositeMap{Float64, Tuple{WarpedTensorProductMap2D{SMatrix{5, 5, Float64, 25}, SArray{Tuple{5, 5, 5}, Float64, 3, 125}, SMatrix{5, 5, Int64, 25}, SMatrix{5, 5, Int64, 25}}, LinearMaps.BlockMap{Float64, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}}, Tuple{Int64, Int64, Int64}}}}, LinearMaps.BlockMap{Float64, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}}, Tuple{Int64, Int64, Int64}}, OctavianMap, StableSpectralElements.SpatialDiscretizations.ReferenceMapping}, limits::Tuple{Float64, Float64}, h::Float64; seed::Int64, iterations::Int64)
#
#     @ StableSpectralElements.SpatialDiscretizations ~/Documents/Research/Summer_2025/StableSpectralElements.jl/src/SpatialDiscretizations/mesh.jl:613
#
#  [15] unstructured_periodic_mesh(reference_element::ReferenceApproximation{RefElemData{2, Tri, StartUpDG.Polynomial{StartUpDG.DefaultPolynomialType}, Int64, Tuple{Vector{Int64}, Vector{Int64}, Vector{Int64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Tuple{Vector{Float64}, Vector{Float64}}, Vector{Int64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Tuple{Matrix{Float64}, Matrix{Float64}}, Matrix{Float64}, Matrix{Float64}, Matrix{Float64}, Vector{Float64}, Vector{Float64}}, ModalTensor, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}}, WarpedTensorProductMap2D{SMatrix{5, 5, Float64, 25}, SArray{Tuple{5, 5, 5}, Float64, 3, 125}, SMatrix{5, 5, Int64, 25}, SMatrix{5, 5, Int64, 25}}, LinearMaps.CompositeMap{Float64, Tuple{WarpedTensorProductMap2D{SMatrix{5, 5, Float64, 25}, SArray{Tuple{5, 5, 5}, Float64, 3, 125}, SMatrix{5, 5, Int64, 25}, SMatrix{5, 5, Int64, 25}}, LinearMaps.BlockMap{Float64, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}}, Tuple{Int64, Int64, Int64}}}}, LinearMaps.BlockMap{Float64, Tuple{LinearMaps.KroneckerMap{Float64, Tuple{LinearMaps.UniformScalingMap{Bool}, OctavianMap}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}, LinearMaps.KroneckerMap{Float64, Tuple{OctavianMap, LinearMaps.UniformScalingMap{Bool}}}}, Tuple{Int64, Int64, Int64}}, OctavianMap, StableSpectralElements.SpatialDiscretizations.ReferenceMapping}, limits::Tuple{Float64, Float64}, h::Float64)
#
#     @ StableSpectralElements.SpatialDiscretizations ~/Documents/Research/Summer_2025/StableSpectralElements.jl/src/SpatialDiscretizations/mesh.jl:567
#
#  [16] eval
#
#     @ ./boot.jl:430 [inlined]
#
#  [17] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:2734
#
#  [18] #invokelatest#2
#
#     @ ./essentials.jl:1055 [inlined]
#
#  [19] invokelatest
#
#     @ ./essentials.jl:1052 [inlined]
#
#  [20] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [21] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/packages/VSCodeServer/src/repl.jl:276
#
#  [22] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, params::VSCodeServer.NotebookRunCellArguments)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [23] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::Dict{String, Any})
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/packages/JSONRPC/src/typed.jl:67
#
#  [24] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
#
#  [25] top-level scope
#
#     @ ~/.vscode/extensions/julialang.language-julia-1.127.2/scripts/notebook/notebook.jl:35

# %% [markdown]
# We'll now plot the mesh, showing the volume and facet quadrature nodes.

# %%
plot(spatial_discretization, fmt=:png)

# %% [markdown]
# Using the `semidiscretize` function, we can create an `ODEProblem` object for use with OrdinaryDiffEq.jl's `solve` function.

# %%
ode_problem = semidiscretize(conservation_law,
    spatial_discretization, exact_solution, form, (0.0, T))
println(size(ode_problem.u0))
CFL = 0.1
h = L/sqrt(reference_approximation.N_p * spatial_discretization.N_e)
dt = CFL * h / sqrt(a[1]^2 + a[2]^2)
#dt = 4.1666666666666665e-5
println(dt)
#println(Threads.nthreads())

reset_timer!()
sol = solve(ode_problem, DP5(), 
    adaptive=false, dt=dt, save_everystep=false, 
    callback=save_callback(results_path, (0.0,T)))
print_timer()
# Out:
# (15, 1, 292)
# 0.0010684346079267205
# ────────────────────────────────────────────────────────────────────────────────
#                                        Time                    Allocations
#                               ───────────────────────   ────────────────────────
#       Tot / % measured:            14.7s /  95.0%           18.9GiB /  99.2%
#
# Section               ncalls     time    %tot     avg     alloc    %tot      avg
# ────────────────────────────────────────────────────────────────────────────────
# semi-disc. residual    7.49k    14.0s  100.0%  1.86ms   18.7GiB  100.0%  2.56MiB
# ────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# The $L^2$ error in the numerical solution can then be computed as follows using the scheme's volume quadrature rule.

# %%
error_analysis = ErrorAnalysis(results_path, conservation_law, 
    spatial_discretization)
println("L2 error:")
println(analyze(error_analysis, last(sol.u), exact_solution, T)...)
display(analyze(error_analysis, last(sol.u), exact_solution, T)...)
# Out:
# 0.0022502474943461364
# L2 error:
# 0.0022502474943461364

# %% [markdown]
# The conservation and energy functionals can now be evaluated as shown below. The scheme is conservative on the order of machine precision, and energy dissipation is only introduced through the time discretization.

# %%
conservation_analysis = PrimaryConservationAnalysis(results_path, 
    conservation_law, spatial_discretization)
energy_analysis = EnergyConservationAnalysis(results_path, 
    conservation_law, spatial_discretization)
p1 = plot(analyze(conservation_analysis, load_time_steps(results_path)), 
    ylabel="Conservation functional")
p2 = plot(analyze(energy_analysis, load_time_steps(results_path)), 
    ylabel="Energy functional")
plot(p1,p2, size=(600,300),margin=5mm, fmt=:png)

# %% [markdown]
# Using a low-order subdivision of the high-order elements, we can generate `.vtu` solution files for visualization, for example, using ParaView.

# %%
#for i in eachindex(sol.u)
#    postprocess_vtk(spatial_discretization, 
#        string(results_path,"solution_$(i).vtu"), sol.u[i]);
#end
#postprocess_vtk(spatial_discretization, string(results_path,"solution.vtu"), last(sol.u));
